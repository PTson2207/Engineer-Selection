# %%
import pandas as pd
import numpy as np
import featuretools as ft

# %%
prmt = ft.list_primitives()
pd.options.display.max_columns = 150
prmt[prmt.type == 'aggregation']
# Out:
#                 name         type  dask_compatible  koalas_compatible  \
# 0       percent_true  aggregation             True              False
# 1                all  aggregation             True              False
# 2           num_true  aggregation             True              False
# 3                sum  aggregation             True               True
# 4               mode  aggregation            False              False
# 5                min  aggregation             True               True
# 6      n_most_common  aggregation            False              False
# 7             median  aggregation            False              False
# 8              count  aggregation             True               True
# 9    time_since_last  aggregation            False              False
# 10        num_unique  aggregation             True               True
# 11              mean  aggregation             True               True
# ...
